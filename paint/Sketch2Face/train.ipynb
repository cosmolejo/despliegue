# %%
# !pip install sklearn
# !pip install tensorflow
# Out:
# ...
#      |████████████████████████████████| 320.4 MB 16 kB/s s eta 0:00:01    |█████▊                          | 57.6 MB 10.3 MB/s eta 0:00:26
# ...
#      |████████████████████████████████| 65 kB 1.0 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 42 kB 192 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 459 kB 10.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.6 MB 149 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 127 kB 11.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.9 MB 11.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.0 MB 10.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.9 MB 11.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 57 kB 858 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 96 kB 1.5 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 114 kB 8.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 298 kB 6.9 MB/s eta 0:00:01
# ...

# %%
# !chmod 777 train_scripts.sh
# !./train_first.sh
# Out:
# start_epoch 1 epoch_iter 0
# Resuming from epoch 1 at iteration 0
# ./train.py:9: DeprecationWarning: fractions.gcd() is deprecated. Use math.gcd() instead.
#   def lcm(a,b): return abs(a * b)/fractions.gcd(a,b) if a and b else 0
# CustomDatasetDataLoader
# dataset [AlignedDataset] was created
# #training images = 44440
# True
# istrain  True
# global
# Load model from:  ./checkpoints/pretrained/latest_net_G.pth
# Load model from:  ./checkpoints/pretrained/latest_net_D.pth
# create web directory ./checkpoints/pretrained/web...
# gen
# (epoch: 1, iters: 100, time: 0.278) G_GAN: 1.256 G_GAN_Feat: 4.763 G_VGG: 5.999 D_real: 1.060 D_fake: 0.414
# memory.used [MiB], memory.free [MiB]
# 4081 MiB, 1994 MiB
# (epoch: 1, iters: 200, time: 0.263) G_GAN: 0.206 G_GAN_Feat: 8.556 G_VGG: 10.159 D_real: 0.126 D_fake: 1.954
# memory.used [MiB], memory.free [MiB]
# 4078 MiB, 1997 MiB
# (epoch: 1, iters: 300, time: 0.264) G_GAN: 1.548 G_GAN_Feat: 5.545 G_VGG: 5.867 D_real: 0.791 D_fake: 0.328
# ...

# %%
# !chmod 777 train_second.sh

# %%
# !./train_second.sh
# Out:
# True
# start_epoch 16 epoch_iter 43800
# Resuming from epoch 16 at iteration 43800
# ./train.py:9: DeprecationWarning: fractions.gcd() is deprecated. Use math.gcd() instead.
#   def lcm(a,b): return abs(a * b)/fractions.gcd(a,b) if a and b else 0
# CustomDatasetDataLoader
# dataset [AlignedDataset] was created
# #training images = 44440
# True
# istrain  True
# dual
# Load model from:  ./checkpoints/pretrained/10_net_G.pth
# Load model from:  ./checkpoints/pretrained/10_net_G_sap.pth
# Load model from:  ./checkpoints/pretrained/10_net_G.pth
# Load model from:  ./checkpoints/pretrained/10_net_G_sap.pth
# Load model from:  ./checkpoints/pretrained/10_net_D.pth
# ------------- Only training the SAP (for 15 epochs) ------------
# The layers that are finetuned are  ['max_pool', 'model_0', 'model_1', 'model_2', 'model_3', 'model_4']
# model [Pix2PixHDModel] was created
# create web directory ./checkpoints/pretrained/web...
# ...

# %%
# !chmod 777 train_third.sh
# !./train_third.sh
# Out:
# [0]
# start_epoch 31 epoch_iter 0
# Resuming from epoch 31 at iteration 0
# ./train.py:9: DeprecationWarning: fractions.gcd() is deprecated. Use math.gcd() instead.
#   def lcm(a,b): return abs(a * b)/fractions.gcd(a,b) if a and b else 0
# CustomDatasetDataLoader
# dataset [AlignedDataset] was created
# Traceback (most recent call last):
#   File "./train.py", line 43, in <module>
#     data_loader = CreateDataLoader(opt)
#   File "/workspace/IntegradorSketch/ModelosDrawing/Sketch2Face-master/data/data_loader.py", line 6, in CreateDataLoader
#     data_loader.initialize(opt)
#   File "/workspace/IntegradorSketch/ModelosDrawing/Sketch2Face-master/data/custom_dataset_data_loader.py", line 20, in initialize
#     self.dataset = CreateDataset(opt)
#   File "/workspace/IntegradorSketch/ModelosDrawing/Sketch2Face-master/data/custom_dataset_data_loader.py", line 11, in CreateDataset
#     dataset.initialize(opt)
# ...

# %%
# !chmod 777 train_fourth_test1.sh
# !./train_fourth_test1.sh
# Out:
# 2020-12-11 19:33:10.304452: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# [0]
# start_epoch 31 epoch_iter 0
# Resuming from epoch 31 at iteration 0
# ./train.py:9: DeprecationWarning: fractions.gcd() is deprecated. Use math.gcd() instead.
#   def lcm(a,b): return abs(a * b)/fractions.gcd(a,b) if a and b else 0
# CustomDatasetDataLoader
# dataset [AlignedDataset] was created
# #training images = 1000
# True
# global
# Load model from:  ./checkpoints/race_test_1/latest_net_G.pth
# Load model from:  ./checkpoints/race_test_1/latest_net_D.pth
# 2020-12-11 19:33:27.627464: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-11 19:33:27.627609: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !chmod 777 train_fourth_test2.sh
# !./train_fourth_test2.sh
# Out:
# 2020-12-11 20:31:22.158663: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# [0]
# start_epoch 31 epoch_iter 0
# Resuming from epoch 31 at iteration 0
# ./train.py:9: DeprecationWarning: fractions.gcd() is deprecated. Use math.gcd() instead.
#   def lcm(a,b): return abs(a * b)/fractions.gcd(a,b) if a and b else 0
# CustomDatasetDataLoader
# dataset [AlignedDataset] was created
# #training images = 1000
# True
# global
# Load model from:  ./checkpoints/race_test_2/latest_net_G.pth
# Load model from:  ./checkpoints/race_test_2/latest_net_D.pth
# 2020-12-11 20:31:40.516756: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-11 20:31:40.516918: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !chmod 777 train_fourth_test1.sh
# !./train_fourth_test1.sh
